# %%
import requests, lxml
from bs4 import BeautifulSoup
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
#RECURSOS NLTK dataset
#LIBRERIAS PARA PROCESAMIENTO DE DATOS
import pandas as pd
#LIBRERIAS DE TIEMPO DE PROCESAMIENTO
import time
from tqdm import tqdm, trange, tqdm_notebook
from tqdm.notebook import tqdm_notebook
tqdm_notebook.pandas()
import sys
#LIBRERIAS PARA WORD2 VEC
from collections import Counter
from nltk import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
import json
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import os, sys
import seaborn as sns
#import PyPDF2
from nltk import Tree
from spacy import displacy
from spacy.pipeline import DependencyParser
import re
import spacy
from spacy.lang.es import Spanish
from spacy.pipeline import EntityRuler
import nltk
from nltk.corpus import stopwords
from nltk.data import load
from string import punctuation
nltk.download('stopwords')
spanish_stopwords=stopwords.words('spanish')
non_words=list(punctuation)
import sys
sys.path.append("..")
from itertools import chain
import more_itertools as mit
from nltk.corpus import names
from nltk.corpus.reader.util import *
import nltk
from nltk import precision
import collections
import nltk.metrics
from nltk.tokenize import MWETokenizer
nltk.download('names')
import random
from nltk.corpus import names
import nltk
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.

# %%
#CREAR EL CERTIFICADO DE AUTENTICACIÓN
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#traer los modelos desde el drive
downloaded = drive.CreateFile({'id':"1Z4zD9ACOp_XCAXT2NgpNb_aHaGim5BfP"})
downloaded.GetContentFile('diccionario.xlsx')
downloaded = drive.CreateFile({'id':"1XheJDpAkRCE_BDvqJD9Qt-jE2YQIN5zT"})
downloaded.GetContentFile('trainned_model_ar.model')
downloaded = drive.CreateFile({'id':"1tImR1aPQXJwDr2iqttsPjhdMsmzU8Kml"})
downloaded.GetContentFile('trainned_model_bo.model')
downloaded = drive.CreateFile({'id':"1ldJ0EXGxA0226l33Ee-voBdjOCaxAdkX"})
downloaded.GetContentFile('trainned_model_cepal.model')
downloaded = drive.CreateFile({'id':"1WCsNCw6hb9Qv2KNdIQ1ZSiVzoCjN49AG"})
downloaded.GetContentFile('trainned_model_ch.model')
downloaded = drive.CreateFile({'id':"1R1sco6CWAaDcbnG6Vb69zAE4Ga_RcBnS"})
downloaded.GetContentFile('trainned_model_co.model')
downloaded = drive.CreateFile({'id':"1y8CP2vtEFWTd91DU10IRTNvDco2c0ULH"})
downloaded.GetContentFile('trainned_model_cr.model')
downloaded = drive.CreateFile({'id':"1Jf9Jz1SlPRHt4j2BXX33S5qSLbTs9btY"})
downloaded.GetContentFile('trainned_model_ec.model')
downloaded = drive.CreateFile({'id':"1UsFRp5RzdJ4YN69Zzn5zAA7e9RkTgL3F"})
downloaded.GetContentFile('trainned_model_esl.model')
downloaded = drive.CreateFile({'id':"1gjvhpRImpVA3lBF2sMgzN_VeCqUc-uZU"})
downloaded.GetContentFile('trainned_model_gu.model')
downloaded = drive.CreateFile({'id':"1DqDliSEaFwiBlFgl2RxRf7VenpkteN8E"})
downloaded.GetContentFile('trainned_model_mx.model')
downloaded = drive.CreateFile({'id':"1PRy9E6C0el7AZPtfDNfCD_o6CTsnqB_Q"})
downloaded.GetContentFile('trainned_model_ods.model')
downloaded = drive.CreateFile({'id':"1SMlzl6BBanq8YudY6i9kQO-jRBmgdVh4"})
downloaded.GetContentFile('trainned_model_pe.model')
downloaded = drive.CreateFile({'id':"1aO3heIoUU1Wz_2dhKER4HNw-kmQBsM59"})
downloaded.GetContentFile('trainned_model_ur.model')

# %%
downloaded = drive.CreateFile({'id':"1e1k58s1ktFyKpTDpiq5ad_n2izz1LTZY"})
downloaded.GetContentFile('data_completa_google_final_todo.xlsx')
downloaded = drive.CreateFile({'id':"1jis2IyJJZFD_DRyjwjrZ1Q1_mGDGE0EB"})
downloaded.GetContentFile('data_completa_google_chile_final.csv')

# %%
downloaded = drive.CreateFile({'id':"1a77v4EsmHywOg84CMcwsVcM_UOSSXdiY"})
downloaded.GetContentFile('data_chile_final_12_05.xlsx')

# %%
downloaded = drive.CreateFile({'id':"137X9PzhZOv0p45fsvJp-iAS3ma2125ub"})
downloaded.GetContentFile('data_todos_final_12_05.xlsx')

# %%
# Construction from scratch
from spacy.vocab import Vocab
from spacy.language import Language

# %%
#PREPROCESO DE TEXTO DE LA TESIS, EN LA COLUMNA TEXTO (RESUMEN DE LA TESIS)
def preprocess(text):
    nlp = Language(Vocab())
    #nlp = spacy.load("xx_ent_wiki_sm")
    result= []
    for i in trange(0,len(text)):
        text[i]=str(text[i])
        text[i]=re.sub(u'^(?<![a-z A-Z])',' ',text[i])
        text[i]=text[i].lower()
        text[i]=text[i].replace('\n',' ')
        text[i]=text[i].replace('"',' ')
        text[i]=text[i].replace('(',' ')
        text[i]=text[i].replace(')',' ')
        text[i]=text[i].replace(']',' ')
        text[i]=text[i].replace('[',' ')
        text[i]=text[i].replace('/',' ')
        text[i]=text[i].replace('%',' ')
        text[i]=text[i].replace('+',' ')
        text[i]=text[i].replace('-',' ')
        text[i]=text[i].replace('.',' ')
        text[i]=text[i].replace(';',' ')
        text[i]=text[i].replace(':',' ')
        text[i]=text[i].replace('|',' ')
        text[i]=text[i].replace('*',' ')
        text[i]=text[i].replace('—',' ')
        text[i]=text[i].replace('€',' ')
        text[i]=text[i].replace('\\n',' ')
        text[i]=text[i].replace(',','')
        text[i]=text[i].replace(' aqui ',' ')
        text[i]=text[i].replace('cuales ',' ')
        text[i]=text[i].replace('toda ',' ')
        text[i]=text[i].replace('cada ',' ')
        text[i]=text[i].replace(' lo ',' ')
        text[i]=text[i].replace(' de ','  ')
        a,b = 'áéíóúü','aeiouu'
        trans = str.maketrans(a,b)
        text[i]=text[i].translate(trans)
        text[i]=text[i].strip()
        doc=nlp(text[i])
        t=[token.text for token in doc]
        result.append(' '.join(list(t)))
    return result

# %%
#APLICAR LA FUNCION PREPROCESS
#db=pd.read_csv('data_completa_google_chile_final.csv')
#db1=db.drop(['Unnamed: 0.4','Unnamed: 0.3','Unnamed: 0.2','Unnamed: 0','Unnamed: 0.1'], axis=1)

# %%
#db2=pd.read_excel('data_completa_google_final_todo.xlsx')
#db22=db2.drop(['Unnamed: 0.4','Unnamed: 0.3','Unnamed: 0.2','Unnamed: 0','Unnamed: 0.1'], axis=1)
#db22.head()

# %%
#db=pd.read_excel('data_chile_final_12_05.xlsx')
db=pd.read_excel('data_todos_final_12_05.xlsx')
db=db.drop(['Unnamed: 0'], axis=1)

# %%
db.columns
# Out:
# Index(['titulo', 'autores', 'dc.title', 'dc.type', 'Link_tesis', 'data_text',
#        'dc.language', 'organic_results', 'organic_results_json', 'Citas',
#        'Versiones', 'Universidad', 'Pais', 'Prep_u'],
#       dtype='object')

# %%
db['Prep_text']=preprocess(db['data_text'])
# Out:
#   0%|          | 0/18657 [00:00<?, ?it/s]<ipython-input-52-0f1b9983c50d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text[i]=str(text[i])
# <ipython-input-52-0f1b9983c50d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text[i]=re.sub(u'^(?<![a-z A-Z])',' ',text[i])
# <ipython-input-52-0f1b9983c50d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text[i]=text[i].lower()
# ...

# %%
#OBTENER EL DICCIONARIO
diccionario=pd.read_excel('diccionario.xlsx')

# %%
#aplicara los Tituloes el FINDSPAN
import sys
sys.path.append("..")
from itertools import chain
import more_itertools as mit
import pandas as pd
import spacy
import os
import re
# Construction from scratch
#GET THE PARAMETERS FOR Find_span
class SpanFinder:
    def __init__(self, io, sheet2):
        self.io = io
        self.sheet2 = sheet2
        self.patterns = self.read_patterns()
        self.nlp = self.set_nlp()
        #self.diccionary_o = self.diccionary_o()
        self.trans = self.make_trans()

    #FIND SPAN FUNCTION
    def read_patterns(self):#,Type_file_dict):
        df=pd.read_excel(self.io,sheet_name=self.sheet2)#diccionary_o)
        df=df.rename(columns={'Unnamed: 0':'label'})
        df=df.replace('a','NaN')
        df=df.replace('s','NaN')
        df=df.replace('e','NaN')
        df=df.replace('m','NaN')
        df=df.replace('n','NaN')
        df=df.replace('n','NaN')
        df0=df[['label','pattern']]
            #carga el diccionario por label
        for k in range(1,len(df.columns)-1):
                exec(f'df{k} = df[["label","pattern.{k}"]]')
                #rename las columnas
        sheets=[]
        for var in dir():
            if isinstance(locals()[var], pd.core.frame.DataFrame)  and var[0]!='_':
                sheets.append(var)
        df_list=[]
        for i in range(1,len(sheets)):
            df_list.append(eval(sheets[i]))

            #rename patterns columns
        for k in range(0,len(df_list)):#(len(df.columns)-2)):
            df_list[k]=df_list[k].rename(columns={df_list[k].columns[1]:"pattern"}, inplace = False)
            #diccionario
        for k in range(0,len(df_list)):
            exec(f'patterns{k+1} = df_list[k].to_dict(orient="records")')
        patt_list=[]
        for var in dir():
            if var.startswith('patterns')==True and var[0]!='_':
                patt_list.append(eval(var))
        patterns=[]
        for i in range(0,len(patt_list)):
            patterns= patterns+patt_list[i]
        #patterns=Diccionary_var
        return patterns
    def set_nlp(self):
        #Crear el objeto NLP
        #nlp = Language()
        nlp = Language(Vocab())
        ruler = nlp.add_pipe("entity_ruler")
        #ruler = EntityRuler(nlp)
        ruler.add_patterns(self.patterns)
        #nlp.add_pipe(ruler)
        return nlp
    def make_trans(self):
        #Preprocesar la entrada
        a,b = 'áéíóúü','aeiouu'
        trans = str.maketrans(a,b)
        return trans

    def find_span(self, sentence):
        sentence=str(sentence).lower().translate(self.trans)
        doc = self.nlp(sentence)
        #Devuelve la etiqueta real de la entidad
        if (sentence=='' or  sentence==' ' or sentence=='Por definir' or sentence=='por definir' or
           sentence=='no hay datos ' or sentence=='nan'):
            label=['No encontrado']#con esto evitaremos el rpoblema de comillas
        else:
            #label= list(set([(ent.label_) for ent in doc.ents]))
            label= list(set([(ent.text) for ent in doc.ents]))
        #label no establecida
        if label!=[]:
            label=label
        else: label=['No encontrado']#con esto evitaremos el problema de comillas

        return  label[0]

# %%
#APLICAR LA FUNCION FindSpan para obtener las palabras clave EN EL RESUMEN
#DCUBE
finder_dcube=SpanFinder('diccionario.xlsx','dcube')
db['DCUBE_R']=db['Prep_text'].progress_apply(finder_dcube.find_span)
# Out:
#   0%|          | 0/18657 [00:00<?, ?it/s]

# %%
#PERU
finder_concy=SpanFinder('diccionario.xlsx','pe')
db['Linea_pais_titulo_pe']=db['dc.title'].progress_apply(finder_concy.find_span)
#BOLIVIA
finder_bo=SpanFinder('diccionario.xlsx','bo')
db['Linea_pais_titulo_bo']=db['dc.title'].progress_apply(finder_bo.find_span)
#CHILE
finder_ch=SpanFinder('diccionario.xlsx','ch')
db['Linea_pais_titulo_ch']=db['dc.title'].progress_apply(finder_ch.find_span)
#COLOMBIA
finder_co=SpanFinder('diccionario.xlsx','co')
db['Linea_pais_titulo_co']=db['dc.title'].progress_apply(finder_co.find_span)
#COSTA RICA
finder_cr=SpanFinder('diccionario.xlsx','cr')
db['Linea_pais_titulo_cr']=db['dc.title'].progress_apply(finder_cr.find_span)
#GUATEMALA
finder_gu=SpanFinder('diccionario.xlsx','gu')
db['Linea_pais_titulo_gu']=db['dc.title'].progress_apply(finder_gu.find_span)
#MEX
finder_mx=SpanFinder('diccionario.xlsx','mx')
db['Linea_pais_titulo_mx']=db['dc.title'].progress_apply(finder_mx.find_span)
#ARGENTINA
finder_ar=SpanFinder('diccionario.xlsx','ar')
db['Linea_pais_titulo_ar']=db['dc.title'].progress_apply(finder_ar.find_span)
#URUGUAY
finder_ur=SpanFinder('diccionario.xlsx','ur')
db['Linea_pais_titulo_ur']=db['dc.title'].progress_apply(finder_ur.find_span)
#ECUADOR
finder_ec=SpanFinder('diccionario.xlsx','ec')
db['Linea_pais_titulo_ec']=db['dc.title'].progress_apply(finder_ec.find_span)
#EL SALVADOR
finder_esl=SpanFinder('diccionario.xlsx','esl')
db['Linea_pais_titulo_esl']=db['dc.title'].progress_apply(finder_esl.find_span)
# Out:
# ...
#   0%|          | 0/18657 [00:00<?, ?it/s]

# %%
#PERU
finder_concy=SpanFinder('diccionario.xlsx','pe')
db['Linea_pais_ab_pe']=db['Prep_text'].progress_apply(finder_concy.find_span)
#BOLIVIA
finder_bo=SpanFinder('diccionario.xlsx','bo')
db['Linea_pais_ab_bo']=db['Prep_text'].progress_apply(finder_bo.find_span)
#CHILE
finder_ch=SpanFinder('diccionario.xlsx','ch')
db['Linea_pais_ab_ch']=db['Prep_text'].progress_apply(finder_ch.find_span)
#COLOMBIA
finder_co=SpanFinder('diccionario.xlsx','co')
db['Linea_pais_ab_co']=db['Prep_text'].progress_apply(finder_co.find_span)
#COSTA RICA
finder_cr=SpanFinder('diccionario.xlsx','cr')
db['Linea_pais_ab_cr']=db['Prep_text'].progress_apply(finder_cr.find_span)
#GUATEMALA
finder_gu=SpanFinder('diccionario.xlsx','gu')
db['Linea_pais_ab_gu']=db['Prep_text'].progress_apply(finder_gu.find_span)
#MEX
finder_mx=SpanFinder('diccionario.xlsx','mx')
db['Linea_pais_ab_mx']=db['Prep_text'].progress_apply(finder_mx.find_span)
#ARGENTINA
finder_ar=SpanFinder('diccionario.xlsx','ar')
db['Linea_pais_ab_ar']=db['Prep_text'].progress_apply(finder_ar.find_span)
#URUGUAY
finder_ur=SpanFinder('diccionario.xlsx','ur')
db['Linea_pais_ab_ur']=db['Prep_text'].progress_apply(finder_ur.find_span)
#ECUADOR
finder_ec=SpanFinder('diccionario.xlsx','ec')
db['Linea_pais_ab_ec']=db['Prep_text'].progress_apply(finder_ec.find_span)
#EL SALVADOR
finder_esl=SpanFinder('diccionario.xlsx','esl')
db['Linea_pais_ab_esl']=db['Prep_text'].progress_apply(finder_esl.find_span)
# Out:
# ...
#   0%|          | 0/18657 [00:00<?, ?it/s]

# %%
#IMPORTAR EL MODELO ENTRENADO CON LOS DOCUMENTOS ESPECIFICOS
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import Word2Vec
model_pe = Word2Vec.load("/content/trainned_model_pe.model")
model_ar = Word2Vec.load("/content/trainned_model_ar.model")
model_bo = Word2Vec.load("/content/trainned_model_bo.model")
model_ch = Word2Vec.load("/content/trainned_model_ch.model")
model_co = Word2Vec.load("/content/trainned_model_co.model")
model_cr = Word2Vec.load("/content/trainned_model_cr.model")
model_ec = Word2Vec.load("/content/trainned_model_ec.model")
model_esl = Word2Vec.load("/content/trainned_model_esl.model")
model_gu = Word2Vec.load("/content/trainned_model_gu.model")
model_mx = Word2Vec.load("/content/trainned_model_mx.model")
model_ods = Word2Vec.load("/content/trainned_model_ods.model")
model_ur = Word2Vec.load("/content/trainned_model_ur.model")
model_cepal = Word2Vec.load("/content/trainned_model_cepal.model")
#model_dcube= Word2Vec.load("data/model/trainned_model_NCUBE.model")

# %%
#funcion similitud con el modelo WORD2VEC
def simili_w2v(palabra, model):
  try:
    simi=model.wv.most_similar(palabra, topn=1)
  except KeyError:
    simi=('No encontrado',0)
  return simi[0][1]

# %%
finder_cepal=SpanFinder('diccionario.xlsx','cepal')
db['Linea_cepal_ab']=db['Prep_text'].progress_apply(finder_cepal.find_span)
# Out:
#   0%|          | 0/18657 [00:00<?, ?it/s]

# %%
#columna=db['Linea_DCube'].progress_apply(lambda x: simili_w2v(x, model_dcube))
db['Simi_cepal']=db['Linea_cepal_ab'].progress_apply(lambda x: simili_w2v(x, model_cepal))
#db['Simi_ods']=db['Linea_ods'].progress_apply(lambda x: simili_w2v(x, model_ods))
# Out:
#   0%|          | 0/18657 [00:00<?, ?it/s]

# %%
db['Simi_pe']=db['Linea_pais_ab_pe'].progress_apply(lambda x: simili_w2v(x, model_pe))
db['Simi_bo']=db['Linea_pais_ab_bo'].progress_apply(lambda x: simili_w2v(x, model_bo))
db['Simi_ch']=db['Linea_pais_ab_ch'].progress_apply(lambda x: simili_w2v(x, model_ch))
db['Simi_co']=db['Linea_pais_ab_co'].progress_apply(lambda x: simili_w2v(x, model_co))
db['Simi_cr']=db['Linea_pais_ab_cr'].progress_apply(lambda x: simili_w2v(x, model_cr))
db['Simi_gu']=db['Linea_pais_ab_gu'].progress_apply(lambda x: simili_w2v(x, model_gu))
db['Simi_mx']=db['Linea_pais_ab_mx'].progress_apply(lambda x: simili_w2v(x, model_mx))
db['Simi_ar']=db['Linea_pais_ab_ar'].progress_apply(lambda x: simili_w2v(x, model_ar))
db['Simi_ur']=db['Linea_pais_ab_ur'].progress_apply(lambda x: simili_w2v(x, model_ur))
db['Simi_ec']=db['Linea_pais_ab_ec'].progress_apply(lambda x: simili_w2v(x, model_ec))
db['Simi_esl']=db['Linea_pais_ab_esl'].progress_apply(lambda x: simili_w2v(x, model_esl))
# Out:
# ...
#   0%|          | 0/18657 [00:00<?, ?it/s]

# %%
#APLICAR LA FUNCION FindSpan para obtener las palabras clave EN EL RESUMEN
#ODS
finder_DSA=SpanFinder('diccionario.xlsx','dsa')
db['DSA']=db['Prep_text'].progress_apply(finder_DSA.find_span)
#dsi
finder_DSI=SpanFinder('diccionario.xlsx','dsi')
db['DSI']=db['Prep_text'].progress_apply(finder_DSI.find_span)
#dsi
finder_DSG=SpanFinder('diccionario.xlsx','dsg')
db['DSG']=db['Prep_text'].progress_apply(finder_DSG.find_span)
#dsi
finder_DSE=SpanFinder('diccionario.xlsx','dse')
db['DSE']=db['Prep_text'].progress_apply(finder_DSE.find_span)
#dsi
finder_DSD=SpanFinder('diccionario.xlsx','dsd')
db['DSD']=db['Prep_text'].progress_apply(finder_DSD.find_span)
#dsi
finder_DSC=SpanFinder('diccionario.xlsx','dsc')
db['DSC']=db['Prep_text'].progress_apply(finder_DSC.find_span)
# Out:
# ...
#   0%|          | 0/18657 [00:00<?, ?it/s]

# %%
db.to_excel('FINAL_todo.xlsx')
