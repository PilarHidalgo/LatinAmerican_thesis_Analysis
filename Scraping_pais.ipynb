# %%
#IMPORTAR LAS LIBRERIAS
import requests, lxml
from bs4 import BeautifulSoup
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
#LIBRERIAS PARA PROCESAMIENTO DE DATOS
import pandas as pd
#LIBRERIAS DE TIEMPO DE PROCESAMIENTO
import time
from tqdm import tqdm, trange, tqdm_notebook
from tqdm.notebook import tqdm_notebook
tqdm_notebook.pandas()
import sys
#LIBRERIAS PARA WORD2 VEC
from collections import Counter
from nltk import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
import json

# %%
import pandas as pd
db=pd.read_excel("DATA_FINAL_MAYO2 (1).xlsx")
db.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'dc.type', 'dc.language', 'Link_thesis',
#        'Citations', 'Versions', 'University', 'Prep_u', 'Country',
#        'DCUBE topics', 'Country research keywords in title',
#        'Country research keywords in abstract',
#        'ECLAC research keywords in abstract', 'Similarity with ECLAC topics',
#        'Similarity with country topics', 'DSA', 'DSI', 'DSG', 'DSE', 'DSD',
#        'DSC', 'Similarity with environment topics',
#        'Similarity with equality topics', 'Similarity with government topics',
#        'Similarity with economical topics',
#        'Similarity with demographic topics',
#        'Similarity with cultural topics'],
#       dtype='object')

# %%
from bs4 import BeautifulSoup
import requests

# %%
db['Link_thesis'][0]
# Out:
# 'https://repositorioslatinoamericanos.uchile.cl/handle/2250/2959084?show=full'

# %%
data_name=[]
data_text=[]
for link in tqdm(db['Link_thesis']):
  r = requests.get(link)
  soup = BeautifulSoup(r.text, 'html')
  table = soup.find_all('table',{"class":"ds-includeSet-table detailtable table table-striped table-hover"})
  rows = table[0].find_all('tr')
  data_name1=[]
  data_text1=[]
  for row in tqdm(rows):
      cols_name = row.find_all('td',{'class':"label-cell"})
      cols_text = row.find_all('td',{'class':"word-break"})
      data_name1.append(cols_name[0].text)
      data_text1.append(cols_text[0].text)
  data_name.append(data_name1)
  data_text.append(data_text1)
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 100%|██████████| 27/27 [00:00<00:00, 6935.28it/s]
# ...
# ...
#  38%|███▊      | 6969/18462 [1:30:02<2:42:50,  1.18it/s]

# %%
db['Universidad']=texto
db.to_csv('Datos_junio_2023.csv')

# %%
df=pd.read_excel('Datos_julio_2023_.xlsx')
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'val'], dtype='object')

# %%
db['contenido_tabla']=df['Name']
db['contenido_cabeceras']=df['val']

# %%
import ast
db['Title'][20709]#contenido_tabla'][20709]#="2020"
db['contenido_tabla'][20709]="2017"
# Out:
# <ipython-input-78-b6e67edc6bc5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['contenido_tabla'][20709]="2017"

# %%
x=[]
for i in trange(0, len(db)):
  string=db['contenido_tabla'][i]
  output = eval(string)
  x.append(output)
  #print(output[8])
db['contenido_tabla']=x
# Out:
# 100%|██████████| 20710/20710 [00:01<00:00, 12239.22it/s]

# %%
db['contenido_cabeceras'][2247]="2020"
db['contenido_cabeceras'][20709]="2017"
# Out:
# <ipython-input-84-a3f548145d35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['contenido_cabeceras'][2247]="2020"
# <ipython-input-84-a3f548145d35>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['contenido_cabeceras'][20709]="2017"

# %%
y=[]
for i in trange(0, len(db)):
  string=db['contenido_cabeceras'][i]
  output = eval(string)
  y.append(output)
  #print(output[8])
db['contenido_cabeceras']=y
# Out:
# 100%|██████████| 20710/20710 [00:00<00:00, 25666.89it/s]

# %%
db.to_excel('DATA_FINAL_JULIO1.xlsx')
